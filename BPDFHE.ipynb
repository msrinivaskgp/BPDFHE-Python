# %%
import numpy as np
from skimage import data
import matplotlib.pyplot as plt
import time
from PIL import Image
import skfuzzy as fuzz
import math
import timeit
import fBPDFHE
    
t0 = time.time()*1000;

image = Image.open("5.2.08.tiff")
image = np.array(image)
    
opimg = bpdfhe(image)
    
mean1 = image.mean()
mean0 = opimg.mean()
img2  = mean1/mean0*opimg

t1 = time.time()*1000;
print("%.6f milli seconds" % (t1 - t0))
    
Q = 2*mean1*mean0/(mean1**2+mean0**2)
# Out:
# 9.426270 milli seconds

# %%
plt.imshow(image, cmap='gray')

# %%
plt.imshow(opimg, cmap='gray')
